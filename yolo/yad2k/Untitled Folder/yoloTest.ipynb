# %% [markdown]
# # Verify Images...

# %%
import matplotlib.pyplot as plt
import os

# %matplotlib notebook

# %%
basedir = '/media/bss/Ubuntu HDD/noaa-sealions/noaa_sealions/yolo/yad2k/'
images = os.path.join(basedir, 'images')
images_out = os.path.join(images, 'out')

# %%
os.listdir(images)
# Out:
# ['eagle.jpg',
#  'scream.jpg',
#  'person.jpg',
#  'horses.jpg',
#  'giraffe.jpg',
#  'out',
#  'dog.jpg']

# %% [markdown]
# ## original

# %%
fig, axes = plt.subplots()
x = plt.imread(os.path.join(images, 'dog.jpg'))
plt.imshow(x)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## YOLO

# %%
fig, axes = plt.subplots()
x = plt.imread(os.path.join(images_out, 'dog.jpg'))
plt.imshow(x)
# Out:
# <img src="data:image/png;base64,..." width="640">
