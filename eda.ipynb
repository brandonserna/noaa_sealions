# %% [markdown]
# # Explore Data
# This includes both the smallTrain dataset as well as the full dataset.

# %%
import os
from skimage.data import load
from skimage.util import img_as_ubyte
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import skimage

# %matplotlib notebook

# %%
# Local directories (update)
trainSmall_dir = '/Users/brandon/Documents/Regis_University/noaa/TrainSmall2'
trainSmall = os.path.join(trainSmall_dir, 'Train')
trainSmall_Dotted = os.path.join(trainSmall_dir, 'TrainDotted')
fp = '../data/'

# %% [markdown]
# #### Utility Functions

# %%
def count_images(filepath):
    ''' returns count of .jpg files '''
    return len([i for i in os.listdir(filepath) if i.endswith('.jpg')])
#count_images(trainSmall)
# Out:
# 10

# %%
print('TrainSmall jpg count: ' + str(count_images(trainSmall)))
# Out:
# TrainSmall jpg count: 10

# %% [markdown]
# ## Small Training Data ("TrainSmall2.7.7z")

# %%
small_y = pd.read_csv(os.path.join(trainSmall, 'Train/train.csv'))
small_y.head()
# Out:
#    train_id  adult_males  subadult_males  adult_females  juveniles  pups
# 0         0           62              12            486         42   344
# 1         1            2              20              0         12     0
# 2         2            2               0             38         20     0
# 3         3            8               5             41          7    38
# 4         4            6               9              2          0     0

# %% [markdown]
# ### Dotted Key
#
# <strong>red</strong>: adult males
#
# <strong>magenta</strong>: subadult males
#
# <strong>brown</strong>: adult females
#
# <strong>blue</strong>: juveniles
#
# <strong>green</strong>: pups

# %% [markdown]
# ### Test Verification (ID #42)
# Manually verify count and distribution
#
# Count:
#
# 11 Red (adult male) - correct
#
# 1 Blue (juveniles) - correct
#
# 10 Brown (adult female) - correct
#
# 4 Magenta (subadult male) - correct
#
# 0 pups - correct

# %%
df2 = small_y.loc[small_y['train_id'] == 42]
df2
# Out:
#     train_id  adult_males  subadult_males  adult_females  juveniles  pups
# 42        42            7               4             10          1     0

# %%
fig, axes = plt.subplots()
plt.imshow(plt.imread(os.path.join(dir, 'Train/42.jpg')))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes = plt.subplots()
plt.imshow(plt.imread(os.path.join(dir, 'TrainDotted/42.jpg')))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Full Dataset ("filename.7z")

# %%
files = os.listdir(fp)

# %%
len(files)

# %%
files[:10]

# %%
jpg_imgs = []
for i in files:
    if i.endswith('.jpg'):
        jpg_imgs.append(i)

# %%
print('JPG images: ' + str(len(jpg_imgs)))

# %% [markdown]
# ## Images

# %%
print('Full data jpg count: ' + count_images(fp))
